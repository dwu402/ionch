# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
volts = np.genfromtxt("./protocol-staircaseramp.csv", skip_header=1, dtype=float, delimiter=',')

# %%
plt.plot(volts[:,0], volts[:,1])

# %%
ts_g = np.abs(np.diff(volts[:,1], n=2)) > 1e-6

# %%
volts[2:,0][ts_g]
# Out:
# array([ 0.25  ,  0.2501,  0.3001,  0.7001,  0.9   ,  0.9001,  1.9   ,
#         1.9001,  2.4   ,  2.4001,  3.4   ,  3.4001,  3.9   ,  3.9001,
#         4.4   ,  4.4001,  4.9   ,  4.9001,  5.4   ,  5.4001,  5.9   ,
#         5.9001,  6.4   ,  6.4001,  6.9   ,  6.9001,  7.4   ,  7.4001,
#         7.9   ,  7.9001,  8.4   ,  8.4001,  8.9   ,  8.9001,  9.4   ,
#         9.4001,  9.9   ,  9.9001, 10.4   , 10.4001, 10.9   , 10.9001,
#        11.4   , 11.4001, 11.9   , 11.9001, 12.4   , 12.4001, 12.9   ,
#        12.9001, 13.9   , 13.9001, 14.4   , 14.4001, 14.4101, 14.51  ,
#        14.5101, 14.9   , 14.9001])

# %%
volts[2:,1][ts_g]
# Out:
# array([-120.  , -120.  , -119.99,  -80.  ,   40.  ,   40.  , -120.  ,
#        -120.  ,  -80.  ,  -80.  ,  -40.  ,  -40.  ,  -60.  ,  -60.  ,
#         -20.  ,  -20.  ,  -40.  ,  -40.  ,    0.  ,    0.  ,  -20.  ,
#         -20.  ,   20.  ,   20.  ,    0.  ,    0.  ,   40.  ,   40.  ,
#          20.  ,   20.  ,   40.  ,   40.  ,    0.  ,    0.  ,   20.  ,
#          20.  ,  -20.  ,  -20.  ,    0.  ,    0.  ,  -40.  ,  -40.  ,
#         -20.  ,  -20.  ,  -60.  ,  -60.  ,  -40.  ,  -40.  ,  -80.  ,
#         -80.  ,   40.  ,   40.  ,  -70.  ,  -70.  ,  -70.04, -120.  ,
#        -120.  ,  -80.  ,  -80.  ])

# %%
# %matplotlib notebook

# %%
plt.figure()
plt.plot(volts[:,0], volts[:,1], 'b')
plt.plot(volts[2:,0][ts_g], volts[2:,1][ts_g], 'r.')
# Out:
# <img src="data:image/png;base64,..." width="640">
